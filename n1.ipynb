# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('shopping_trends.csv')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
new_data= ['Subscription Status','Discount Applied','Promo Code Used']

# %%
new_data = ['Subscription Status', 'Discount Applied', 'Promo Code Used']

for col in new_data:
    df[col] = df[col].replace({"Yes": 1, "No": 0})

# %%
df['Previous Purchases'].value_counts().sort_values(ascending=False,inplace=True)

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df['Age'].plot(kind='hist')
plt.title("histogram in Age ")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='str')

# %%
df['Gender'].value_counts().plot(kind='pie')
plt.title("pie in Gender ")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='str')

# %%
df.groupby('Category')['Purchase Amount (USD)'].mean().sort_values(ascending=False)
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
df['Subscription Status'].value_counts().plot(kind='pie')
plt.title("pie chart of 'Subscription Status' ")
plt.show()

# %%
df['Color'].value_counts().head(4).plot(kind='pie')
# Out:
# <Axes: >

# %%
df.columns
# 'Previous Purchases''Frequency of Purchases'
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='str')

# %%
df.head(10).plot(x='Previous Purchases',y='Review Rating', kind='scatter')
plt.title("Scatter plot Previous Purchases Review Rating ")
plt.show()

# %%
df.groupby('Season')[ 'Purchase Amount (USD)'].sum()
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase Amount (USD), dtype: int64

# %%
df.boxplot(column='Purchase Amount (USD)',by='Frequency of Purchases')
plt.title("boxplot is 'Purchase Amount (USD)' and 'Frequency of Purchases' ``")
plt.show()

# %%
df['Preferred Payment Method'].value_counts().sort_values(ascending=False).head(2)
# Out:
# Preferred Payment Method
# PayPal         677
# Credit Card    671
# Name: count, dtype: int64

# %%
pd.pivot_table(data=df, values='Purchase Amount (USD)',index='Location',columns='Item Purchased',aggfunc='mean').head(5)
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# ...

# %%
df.groupby('Size')['Purchase Amount (USD)'].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Payment Method')['Purchase Amount (USD)'].mean()
# Out:
# Payment Method
# Bank Transfer    58.738924
# Cash             59.927469
# Credit Card      61.159483
# Debit Card       58.638231
# PayPal           58.697492
# Venmo            61.241960
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Discount Applied')['Review Rating'].max()
# Out:
# Discount Applied
# 0    5.0
# 1    5.0
# Name: Review Rating, dtype: float64

# %%
df.groupby('Color')['Category'].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
 #'Previous Purchases''Frequency of Purchases'
df.groupby('Frequency of Purchases')['Previous Purchases'].median()
# Out:
# Frequency of Purchases
# Annually          24.0
# Bi-Weekly         24.0
# Every 3 Months    24.0
# Fortnightly       26.0
# Monthly           25.0
# Quarterly         28.0
# Weekly            26.0
# Name: Previous Purchases, dtype: float64

# %%
df.groupby('Season')['Review Rating'].mean()
# Out:
# Season
# Fall      3.729949
# Spring    3.790591
# Summer    3.725654
# Winter    3.752111
# Name: Review Rating, dtype: float64

# %%
df['Season'].value_counts().plot(kind='bar')
plt.xlabel("Season")
plt.ylabel('Count')
plt.title('count of Purchases in Each Season')
plt.show()

# %%
df.Category.value_counts().plot(kind='pie')
plt.title("Distrpoion of paeschaesn of Category")
plt.show()

# %%
df.boxplot(column='Review Rating', by='Gender')
plt.xlabel("Gender")
plt.ylabel('Review Rating')
plt.title('Review Rating as Gender ')
plt.show()

# %%
df['Purchase Amount (USD)'].plot(kind='hist',bins=10)
plt.xlabel('USD')
plt.ylabel("Frecouncty ")
plt.title("histograme of Purchase Amount Distruboutions  ")
plt.show()

# %%
df.groupby('Color')['Review Rating'].mean().head(5).plot(kind='bar')
plt.xlabel("Color")
plt.ylabel("mean Review Rating ")
plt.title("mean Review Rating for Each Color ")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='str')

# %%
df.groupby("Payment Method")['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.title("Sum of Purchase Amount py Paymeant method ")
plt.ylabel("")
plt.show()

# %%
df.boxplot(column='Purchase Amount (USD)', by='Frequency of Purchases')
plt.xlabel("'Frequency of Purchases'")
plt.ylabel("Purchase Amount ")
plt.title('Purchase Amount Disctripion by Frequency of Purchases')
plt.show()

# %%
df.groupby('Season')['Purchase Amount (USD)'].sum().plot(kind='pie')
# Out:
# <Axes: >
